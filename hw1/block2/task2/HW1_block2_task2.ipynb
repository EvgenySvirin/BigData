# %%
# !pip install MRJob
# !pip install pyarrow
# !pip install pyplot
# !pip install matplotlib

# %% [markdown]
# Локальные решения:

# %%
# !python3 map_reducer2.py SW/SW_EpisodeIV.txt >out2_episode4.txt  && cat out2_episode4.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/map_reducer2.root.20240203.191025.096056
# Running step 1 of 2...
# Running step 2 of 2...
# job output is in /tmp/map_reducer2.root.20240203.191025.096056/output
# Streaming final output from /tmp/map_reducer2.root.20240203.191025.096056/output...
# Removing temp directory /tmp/map_reducer2.root.20240203.191025.096056...
# ...

# %%
# !python3 map_reducer2.py SW/SW_EpisodeV.txt >out2_episode5.txt  && cat out2_episode5.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/map_reducer2.root.20240203.191049.125804
# Running step 1 of 2...
# Running step 2 of 2...
# job output is in /tmp/map_reducer2.root.20240203.191049.125804/output
# Streaming final output from /tmp/map_reducer2.root.20240203.191049.125804/output...
# Removing temp directory /tmp/map_reducer2.root.20240203.191049.125804...
# "YODA"	"Ready, are you? What know you of ready? For eight hundred years  have I trained Jedi. My own counsel will I keep on who is to be trained! A Jedi must have the deepest commitment, the most serious mind.  This one a long time have I watched. Never his mind on where he was. Hmm? What he was doing. Hmph. Adventure. Heh! Excitement. Heh! A Jedi craves not these things.  You are reckless!"
# ...

# %%
# !python3 map_reducer2.py SW/SW_EpisodeVI.txt >out2_episode6.txt  && cat out2_episode6.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/map_reducer2.root.20240203.191110.284987
# Running step 1 of 2...
# Running step 2 of 2...
# job output is in /tmp/map_reducer2.root.20240203.191110.284987/output
# Streaming final output from /tmp/map_reducer2.root.20240203.191110.284987/output...
# Removing temp directory /tmp/map_reducer2.root.20240203.191110.284987...
# ...

# %%
# !python3 map_reducer2.py SW/SW_EpisodeIV.txt SW/SW_EpisodeV.txt SW/SW_EpisodeVI.txt >out2_episodes456.txt  && cat out2_episodes456.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/map_reducer2.root.20240203.191149.350248
# Running step 1 of 2...
# Running step 2 of 2...
# job output is in /tmp/map_reducer2.root.20240203.191149.350248/output
# Streaming final output from /tmp/map_reducer2.root.20240203.191149.350248/output...
# Removing temp directory /tmp/map_reducer2.root.20240203.191149.350248...
# ...

# %% [markdown]
# Решения на кластере:

# %%
# !python3 map_reducer2.py -r hadoop hdfs://namenode:8020/SW/SW_EpisodeIV.txt --output-dir=hdfs://namenode:8020/SW2/ep4
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for hadoop runner
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 3.3.6
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-3.3.6.jar
# Creating temp directory /tmp/map_reducer2.root.20240203.191336.935108
# uploading working dir files to hdfs:///user/root/tmp/mrjob/map_reducer2.root.20240203.191336.935108/files/wd...
# Copying other local files to hdfs:///user/root/tmp/mrjob/map_reducer2.root.20240203.191336.935108/files/
# Running step 1 of 2...
#   packageJobJar: [/tmp/hadoop-unjar3696177023639753127/] [] /tmp/streamjob1119517095843580531.jar tmpDir=null
#   Connecting to ResourceManager at resourcemanager/172.19.0.4:8032
#   Connecting to ResourceManager at resourcemanager/172.19.0.4:8032
# ...

# %%
# !hadoop fs -cat hdfs://namenode:8020/SW2/ep4/part-00000
# Out:
# "LEIA"	"General Kenobi, years ago you served my father in the Clone Wars.  Now he begs you to help him in his struggle against the Empire.  I regret that I am unable to present my father's request to you in person, but my ship has fallen under attack and I'm afraid my mission to bring you to Alderaan has failed.  I have placed information vital to the survival of the Rebellion into the memory systems of this R2 unit.  My father will know how to retrieve it.  You must see this droid safely delivered to him on Alderaan.  This is our most desperate hour.  Help me, Obi-Wan Kenobi, you're my only hope."
# "BIGGS"	"I feel for you, Luke, you're going to have to learn what seems to be important or what really is important.  What good is all your uncle's work if it's taken over by the Empire?...  You know they're starting to nationalize commerce in the central systems...it won't be long before your uncle is merely a tenant, slaving for the greater glory of the Empire."
# ...

# %%
# !python3 map_reducer2.py -r hadoop hdfs://namenode:8020/SW/SW_EpisodeV.txt --output-dir=hdfs://namenode:8020/SW2/ep5
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for hadoop runner
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 3.3.6
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-3.3.6.jar
# Creating temp directory /tmp/map_reducer2.root.20240203.191620.945950
# uploading working dir files to hdfs:///user/root/tmp/mrjob/map_reducer2.root.20240203.191620.945950/files/wd...
# Copying other local files to hdfs:///user/root/tmp/mrjob/map_reducer2.root.20240203.191620.945950/files/
# Running step 1 of 2...
#   packageJobJar: [/tmp/hadoop-unjar3642919966385625707/] [] /tmp/streamjob3162221472682218896.jar tmpDir=null
#   Connecting to ResourceManager at resourcemanager/172.19.0.4:8032
#   Connecting to ResourceManager at resourcemanager/172.19.0.4:8032
# ...

# %%
# !hadoop fs -cat hdfs://namenode:8020/SW2/ep5/part-00000
# Out:
# "YODA"	"Ready, are you? What know you of ready? For eight hundred years  have I trained Jedi. My own counsel will I keep on who is to be trained! A Jedi must have the deepest commitment, the most serious mind.  This one a long time have I watched. Never his mind on where he was. Hmm? What he was doing. Hmph. Adventure. Heh! Excitement. Heh! A Jedi craves not these things.  You are reckless!"
# "VADER"	"There is no escape. Don't make me destroy you. You do not yet  realize your importance. You have only begun to discover you power. Join me and I will complete your training. With our combined strength, we can end this destructive conflict and bring order to the galaxy."
# "LEIA"	"All troop carriers will assemble at the north entrance. The  heavy transport ships will leave as soon as they're loaded. Only two fighter escorts per ship. The energy shield can only be opened for a short time, so you'll have to stay very close to your transports."
# ...

# %%
# !python3 map_reducer2.py -r hadoop hdfs://namenode:8020/SW/SW_EpisodeVI.txt --output-dir=hdfs://namenode:8020/SW2/ep6
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for hadoop runner
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 3.3.6
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-3.3.6.jar
# Creating temp directory /tmp/map_reducer2.root.20240203.191708.913304
# uploading working dir files to hdfs:///user/root/tmp/mrjob/map_reducer2.root.20240203.191708.913304/files/wd...
# Copying other local files to hdfs:///user/root/tmp/mrjob/map_reducer2.root.20240203.191708.913304/files/
# Running step 1 of 2...
#   packageJobJar: [/tmp/hadoop-unjar6568544244559665047/] [] /tmp/streamjob3190287483705582718.jar tmpDir=null
#   Connecting to ResourceManager at resourcemanager/172.19.0.4:8032
#   Connecting to ResourceManager at resourcemanager/172.19.0.4:8032
# ...

# %%
# !hadoop fs -cat hdfs://namenode:8020/SW2/ep6/part-00000
# Out:
# "BEN"	"The Organa household was high-born and politically quite powerful in that system. Leia became a princess by virtue of lineage... no one knew she'd been adopted, of course. But it was a title without real power, since Alderaan had long been a democracy.  Even so, the family continued to be politically powerful, and Leia, following in her foster father's path, became a senator as well.  That's not all she became, of course... she became the leader of her cell in the Alliance against the corrupt Empire. And because she had diplomatic immunity, she was a vital link for getting information to the Rebel cause.  That's what she was doing when her path crossed yours... for her foster parents had always told her to contact me on Tatooine, if her troubles became desperate."
# ...

# %%
# !python3 map_reducer2.py -r hadoop hdfs://namenode:8020/SW/SW_EpisodeIV.txt hdfs://namenode:8020/SW/SW_EpisodeV.txt hdfs://namenode:8020/SW/SW_EpisodeVI.txt --output-dir=hdfs://namenode:8020/SW2/ep456
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for hadoop runner
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 3.3.6
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-3.3.6.jar
# Creating temp directory /tmp/map_reducer2.root.20240203.191754.470373
# uploading working dir files to hdfs:///user/root/tmp/mrjob/map_reducer2.root.20240203.191754.470373/files/wd...
# Copying other local files to hdfs:///user/root/tmp/mrjob/map_reducer2.root.20240203.191754.470373/files/
# Running step 1 of 2...
#   packageJobJar: [/tmp/hadoop-unjar6985762968006635578/] [] /tmp/streamjob4840187992992503058.jar tmpDir=null
#   Connecting to ResourceManager at resourcemanager/172.19.0.4:8032
#   Connecting to ResourceManager at resourcemanager/172.19.0.4:8032
# ...

# %%
# !hadoop fs -cat hdfs://namenode:8020/SW2/ep456/part-00000
# Out:
# "BEN"	"The Organa household was high-born and politically quite powerful in that system. Leia became a princess by virtue of lineage... no one knew she'd been adopted, of course. But it was a title without real power, since Alderaan had long been a democracy.  Even so, the family continued to be politically powerful, and Leia, following in her foster father's path, became a senator as well.  That's not all she became, of course... she became the leader of her cell in the Alliance against the corrupt Empire. And because she had diplomatic immunity, she was a vital link for getting information to the Rebel cause.  That's what she was doing when her path crossed yours... for her foster parents had always told her to contact me on Tatooine, if her troubles became desperate."
# ...
